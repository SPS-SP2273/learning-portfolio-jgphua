# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# ## Exercise 1 (Tidying a collaboration) ☻

# %% [markdown]
# ### Task 1

# %%
month_dictionary = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

# %%
data = 'oct-08_singapore.txt'

# %%
month = data.split('-')[0] #split at - to extract out the month to change
print(month)
# Out:
# oct

# %%
city = data.split('_')[1] #split at - to extract out the month to change
print(city)
# Out:
# singapore.txt

# %%
month_dictionary[month]
# Out:
# '10'

# %%
print(f"{month_dictionary[month]}-{data.split('-')[1]}") #- and _ to split, #need to change _ to - for output
# Out:
# 10-08_singapore.txt

# %%
new_month = data.split("_")[0]
print(new_month)
# Out:
# oct-08

# %%
date = new_month.split("-")[1]
print(date)
# Out:
# 08

# %%
print(f"{month_dictionary[month]}-{new_month.split('-')[1]}-{data.split('_')[1]}")
# Out:
# 10-08-singapore.txt

# %%
print(f"{month_dictionary[month]}-{date}-{city}")
# Out:
# 10-08-singapore.txt

# %% [markdown]
# ### Task 2

# %%
def rename_my_file(old_file_name):
    month = old_file_name.split('-')[0] #copied over same code but changed to old_file_name instead of data
    date_month = old_file_name.split('_')[0]
    date = date_month.split('-')[1]
    city_extension = old_file_name.split('_')[1]
    new_file_name = f"{month_dictionary[month]}-{date}-{city_extension}"
    return new_file_name

# %%
rename_my_file("apr-12_singapore.txt")
# Out:
# '04-12-singapore.txt'

# %% [markdown]
# ### Task 3

# %%
data_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

# %%
i = 0 #for accessing of list
new_data_list = [] 
for data in data_list: #using for loops
    new_data = rename_my_file(data_list[i])
    new_data_list.append(new_data) #to grow the list
    i+=1
print(new_data_list) #generated new list but still need to print out the change
# Out:
# ['10-08-singapore.txt', '07-10-cairo.txt', '05-15-dhaka.txt', '05-13-cairo.txt', '10-21-cairo.txt', '01-10-singapore.txt', '06-20-tokyo.txt', '08-06-jakarta.txt', '12-21-karachi.txt', '01-01-tokyo.txt']

# %%
new_data_list = [] 
for data in data_list: #using for loops
    new_data = rename_my_file(data) #removed i variable use as can directly use data, iteration will go through each element
    new_data_list.append(new_data) #to grow the list
    print(f"{data} ----> {new_data}") # incorporated the change into the for loop
print(new_data_list) #generated new list but still need to print out the change
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt
# ['10-08-singapore.txt', '07-10-cairo.txt', '05-15-dhaka.txt', '05-13-cairo.txt', '10-21-cairo.txt', '01-10-singapore.txt', '06-20-tokyo.txt', '08-06-jakarta.txt', '12-21-karachi.txt', '01-01-tokyo.txt']

# %% [markdown]
# ### Task 4

# %%
import os
import glob

# %%
txt_files = glob.glob('*/**/*.txt', recursive=True)

# %%
txt_files = glob.glob('*/**/*.txt', recursive=True)

for file in txt_files:
    try: #added try-except to prevent error if i rerun code
        name = file.split("\\")[1]
        folder = file.split("\\")[0]
        newname = rename_my_file(name)
        newfilename = folder+"\\"+newname # concatenate to get the path again 
        os.rename(file, newfilename) #had to google a method to rename the path as I didnt know how to do so (earlier used f string but i dont think can for this)
    except:
        print(f"file name has changed")
# Out:
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# file name has changed
# ...

# %%
txt_files = glob.glob('os-collaboration-exercise-data/**/*.txt', recursive=True)

path = os.path.join("os-collaboration-exercise-data", "**", "*.txt") #os.path.join creates safe paths for any OS to use (\ or /)

try:
    for file in txt_files:
        name = os.path.split(file)[1] #used split and get file name which is indexed as 1, changed to file instead
        folder = os.path.split(file)[0] #the rest of the path is indexed as 0
        newname = rename_my_file(name)
        newfilename = os.path.join(folder, name) #used os.path.join to get the actual path with seperators
        os.rename(file, newfilename) #had to google a method to rename the path as I didnt know how to do so (earlier used f string but i dont think can for this)
#will not run if file does not exist or name already exists
        print(f"file has been renamed from {file} to {newfilename}") #added to account for changes
except OSError:
    print(f"file name has changed")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[55], line 9
#       7 name = os.path.split(file)[1] #used split and get file name which is indexed as 1, changed to file instead
#       8 folder = os.path.split(file)[0] #the rest of the path is indexed as 0
# ----> 9 newname = rename_my_file(name)
#      10 newfilename = os.path.join(folder, name) #used os.path.join to get the actual path with seperators
#      11 os.rename(file, newfilename) #had to google a method to rename the path as I didnt know how to do so (earlier used f string but i dont think can for this)
#
# Cell In[32], line 5, in rename_my_file(old_file_name)
#       3 date_month = old_file_name.split('_')[0]
#       4 date = date_month.split('-')[1]
# ----> 5 city_extension = old_file_name.split('_')[1]
#       6 new_file_name = f"{month_dictionary[month]}-{date}-{city_extension}"
# ...

# %%
print(folder)
# Out:
# os-collaboration-exercise-data

# %% [markdown]
# ### Task 5

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
os.mkdir('cities') #creates a folder called cities first

for city in cities:
    path = os.path.join('cities', city) #creates each city folder
    print(f'Creating {path}') #this is not needed but can be used to check whether it is working
    os.mkdir(path)
# Out:
# Creating cities\Cairo
# Creating cities\Dhaka
# Creating cities\Jakarta
# Creating cities\Karachi
# Creating cities\Manila
# Creating cities\Melbourne
# Creating cities\Osaka
# Creating cities\Shanghai
# Creating cities\Singapore
# Creating cities\Tokyo

# %% [markdown]
# ### Task 6

# %%
glob.glob("*/*cairo.*") #used relative path by using * instead of limiiting to folder to search
# Out:
# ['os-collaboration-exercise-data\\01-02-cairo.txt',
#  'os-collaboration-exercise-data\\01-03-cairo.txt',
#  'os-collaboration-exercise-data\\01-04-cairo.txt',
#  'os-collaboration-exercise-data\\01-05-cairo.txt',
#  'os-collaboration-exercise-data\\01-07-cairo.txt',
#  'os-collaboration-exercise-data\\01-08-cairo.txt',
#  'os-collaboration-exercise-data\\01-09-cairo.txt',
#  'os-collaboration-exercise-data\\01-11-cairo.txt',
#  'os-collaboration-exercise-data\\01-12-cairo.txt',
#  'os-collaboration-exercise-data\\01-13-cairo.txt',
#  'os-collaboration-exercise-data\\01-15-cairo.txt',
#  'os-collaboration-exercise-data\\01-16-cairo.txt',
#  'os-collaboration-exercise-data\\01-19-cairo.txt',
#  'os-collaboration-exercise-data\\01-20-cairo.txt',
#  'os-collaboration-exercise-data\\01-21-cairo.txt',
#  'os-collaboration-exercise-data\\01-23-cairo.txt',
#  'os-collaboration-exercise-data\\01-27-cairo.txt',
#  'os-collaboration-exercise-data\\01-30-cairo.txt',
# ...

# %%
import shutil

# %%
cairofiles = glob.glob("**/*cairo.*") #added . behind to remove the search for the folder
#also changed to ** to search not just this folder
for file in cairofiles:
    try:
        path_to_destination = os.path.join('cities', "Cairo")
        shutil.copy(file, path_to_destination) #changed to file
        print(f'Copied {file} to {path_to_destination}') #changed to add in source too for better accounting
    except PermissionError: #added in case of Persmissionerror
        print(f"PermissionError")
# Out:
# Copied os-collaboration-exercise-data\01-02-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-03-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-04-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-05-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-07-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-08-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-09-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-11-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-12-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-13-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-15-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-16-cairo.txt to cities\Cairo
# Copied os-collaboration-exercise-data\01-19-cairo.txt to cities\Cairo
# ...

# %% [markdown]
# ### Task 7

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
for city in cities:
    files = glob.glob(os.path.join("os-collaboration-exercise-data","**")) #finds files within the path
    #used os.path.join to remove need for OS specific seperators and to specify folder
    path_to_destination = os.path.join('cities', city) 
    for file in files: #usage of nested loops
        try:
            shutil.move(file, path_to_destination) #used shutil.move to move files from source to destination
            print(f'Moved file from {file} to {path_to_destination}') #to see whether file actually moved
        except:
            print("File already exists") #account for errors that may occur when file has already been moved
#output shows file already exists as the code was relaunched multiple times to include notes
# Out:
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# File already exists
# ...

# %%
print(os.path.join("os-collaboration-exercise-data", city, "*")) #cannot be used to search files with the city name
# Out:
# os-collaboration-exercise-data\Tokyo\*

# %%
for city in cities:
    files = glob.glob(os.path.join("os-collaboration-exercise-data","**")) #finds files within the path
    #used os.path.join to remove need for OS specific seperators and to specify folder
    path_to_destination = os.path.join('cities', city) 
    for file in files: #usage of nested loops
        filename = file.split(os.path.sep)[-1]
        completed_path = os.path.join("cities", city, filename)
        if os.path.exists(completed_path):
            print(f"{completed_path} exists, file is already moved")
        else:
            #shutil.move(file, path_to_destination) #used shutil.move to move files from source to destination
            print(f'Moved file from {file} to {path_to_destination}') #to see whether file actually moved

# %%
print(completed_path)
# Out:
# cities\Dhaka\sep-28_cairo.png

# %%
print(path_to_destination)
# Out:
# cities\Tokyo

# %%
print(filename)
# Out:
# sep-28_cairo.png
